# %%
import os
import pydicom
import pandas as pd
import numpy as np
from datetime import datetime
import shutil
import pyodbc

# %%
# Identify DICOM files under 'DICOMpath' directory
DICOMpath='D:/bkpnew24/20100325/E7646522'
DICOMlist = []
for (path, dir, files) in os.walk(DICOMpath):
    for filename in files:
        ext = os.path.splitext(filename)[-1]
        if ext == '.dcm':
            filePath = "{0}/{1}".format(path, filename)
            # print(filePath)
            DICOMlist.append(filePath)
Metadata=list(map(lambda x : pydicom.filereader.dcmread(x), DICOMlist))

# %%
def ColumnsFunction(x):
    try:
        return Metadata[x].Columns
    except:
        return 'NA'

# %%
def RowsFunction(x):
    try:
        return Metadata[x].Rows
    except:
        return 'NA'

# %%
def SeriesInstanceFunction(x):
    try:
        return Metadata[x].SeriesInstanceUID
    except:
        return 'NA'

# %%
def SOPInstanceUIDFunction(x):
    try:
        return Metadata[x].SOPInstanceUID
    except:
        return 'NA'

# %%
def StudyInstanceUIDFunction(x):
    try:
        return Metadata[x].StudyInstanceUID
    except:
        return 'NA'

# %%
def PatientIDFunction(x):
    try:
        return Metadata[x].PatientID
    except:
        return 'NA'

# %%
def SliceThicknessFunction(x):
    try:
        return Metadata[x].SliceThickness
    except:
        return 'NA'

# %%
def BodyPartExamined(x):
    try:
        return Metadata[x].BodyPartExamined
    except:
        return 'NA'

# %%
def ProtocolName(x):
    try:
        return Metadata[x].ProtocolName
    except:
        return 'NA'

# %%
def SeriesDescription(x):
    try:
        return Metadata[x].SeriesDescription
    except:
        return 'NA'

# %%
def StudyDescription(x):
    try:
        return Metadata[x].StudyDescription
    except:
        return 'NA'

# %%
def PerformedProcedureStepDescription(x):
    try:
        return Metadata[x].PerformedProcedureStepDescription
    except:
        return 'NA'

# %%
#Create RadiologyImageTable without columns of ImageOrientation, RadiologyPhaseConceptID
RadiologyImageTable=pd.DataFrame({'Filepath': DICOMlist, 'ImageID':list(map(lambda x : SOPInstanceUIDFunction(x), range(len(DICOMlist)))), 
                                  'SeriesID':list(map(lambda x : SeriesInstanceFunction(x), range(len(DICOMlist)))), 
                                  'RadiologyOccurrenceID':list(map(lambda x : StudyInstanceUIDFunction(x), range(len(DICOMlist)))), 
                                  'PatientID':list(map(lambda x : PatientIDFunction(x), range(len(DICOMlist)))), 
                                  'ImageResolutionRows':list(map(lambda x : RowsFunction(x), range(len(DICOMlist)))), 
                                  'ImageResolutionColumns':list(map(lambda x : ColumnsFunction(x), range(len(DICOMlist)))), 
                                  'SliceThickness':list(map(lambda x : SliceThicknessFunction(x), range(len(DICOMlist)))),
                                 'ProtocolName':list(map(lambda x : ProtocolName(x), range(len(DICOMlist)))),
                                 'PerformedProcedureStepDescription':list(map(lambda x : PerformedProcedureStepDescription(x), range(len(DICOMlist)))),
                                 'BodyPartExamined':list(map(lambda x : BodyPartExamined(x), range(len(DICOMlist)))),
                                 'Modality':list(map(lambda x : Modality(x), range(len(DICOMlist)))),
                                 'SeriesDescription':list(map(lambda x : SeriesDescription(x), range(len(DICOMlist)))),
                                 'StudyDescription':list(map(lambda x : StudyDescription(x), range(len(DICOMlist)))),
                                 'Manufacturer':list(map(lambda x : Manufacturer(x), range(len(DICOMlist))))})
grouped=RadiologyImageTable[['ImageID','SeriesID']].groupby('SeriesID')
PhaseTotalNo=grouped.count()
PhaseTotalNo.columns = ['PhaseTotalNo']
RadiologyImageTable['ImageNo']=RadiologyImageTable.groupby(['SeriesID']).cumcount()+1
RadiologyImageTable=pd.merge(RadiologyImageTable, PhaseTotalNo, on='SeriesID')

# %%
SOPInstanceUIDFunction(2)
# Out:
# '4WeTF3VmZQ3BscYaiM443E/2uNrZ6sG2Pe5mpGDa/gG+IMn4fv0bZFARqrT34DeUB+XuxQZrn3AxSZAE5ZVxGw=='

# %%
RadiologyImageTable
# Out:
#                                            Filepath  \
# 0    D:/bkpnew24/20100325/E7646522/I00237923115.dcm
# 1    D:/bkpnew24/20100325/E7646522/I00237923116.dcm
# 2    D:/bkpnew24/20100325/E7646522/I00237923117.dcm
# 3    D:/bkpnew24/20100325/E7646522/I00237923118.dcm
# 4    D:/bkpnew24/20100325/E7646522/I00237923119.dcm
# ..                                              ...
# 119  D:/bkpnew24/20100325/E7646522/I00237923474.dcm
# 120  D:/bkpnew24/20100325/E7646522/I00237923475.dcm
# 121  D:/bkpnew24/20100325/E7646522/I00237923476.dcm
# 122  D:/bkpnew24/20100325/E7646522/I00237923477.dcm
# 123  D:/bkpnew24/20100325/E7646522/I00237923478.dcm
#
#                                                ImageID  \
# 0    4WeTF3VmZQ3BscYaiM443E/2uNrZ6sG2Pe5mpGDa/gG+IM...
# 1    4WeTF3VmZQ3BscYaiM443E/2uNrZ6sG2Pe5mpGDa/gG+IM...
# 2    4WeTF3VmZQ3BscYaiM443E/2uNrZ6sG2Pe5mpGDa/gG+IM...
# 3    4WeTF3VmZQ3BscYaiM443E/2uNrZ6sG2Pe5mpGDa/gG+IM...
# 4    4WeTF3VmZQ3BscYaiM443E/2uNrZ6sG2Pe5mpGDa/gG+IM...
# ..                                                 ...
# 119  4WeTF3VmZQ3BscYaiM443E/2uNrZ6sG2Pe5mpGDa/gG+IM...
# 120  4WeTF3VmZQ3BscYaiM443E/2uNrZ6sG2Pe5mpGDa/gG+IM...
# 121  4WeTF3VmZQ3BscYaiM443E/2uNrZ6sG2Pe5mpGDa/gG+IM...
# 122  4WeTF3VmZQ3BscYaiM443E/2uNrZ6sG2Pe5mpGDa/gG+IM...
# 123  n6wLQbmyp2DaFxadwFOwi3qrjk7swSLy0L/mOQcdR4adRX...
#
#                                               SeriesID  \
# 0    kRHGsxTA10eb2TyHtfuCNZHY+jWXVLlZaWQ7RqNdrPKpMS...
# 1    kRHGsxTA10eb2TyHtfuCNZHY+jWXVLlZaWQ7RqNdrPKpMS...
# 2    kRHGsxTA10eb2TyHtfuCNZHY+jWXVLlZaWQ7RqNdrPKpMS...
# 3    kRHGsxTA10eb2TyHtfuCNZHY+jWXVLlZaWQ7RqNdrPKpMS...
# 4    kRHGsxTA10eb2TyHtfuCNZHY+jWXVLlZaWQ7RqNdrPKpMS...
# ..                                                 ...
# 119  kRHGsxTA10eb2TyHtfuCNZHY+jWXVLlZaWQ7RqNdrPKpMS...
# 120  kRHGsxTA10eb2TyHtfuCNZHY+jWXVLlZaWQ7RqNdrPKpMS...
# 121  kRHGsxTA10eb2TyHtfuCNZHY+jWXVLlZaWQ7RqNdrPKpMS...
# 122  kRHGsxTA10eb2TyHtfuCNZHY+jWXVLlZaWQ7RqNdrPKpMS...
# 123  +03QDkRYnlCIXr7pVIm58j9CrCEyFRn6QIN11s2No3Y10c...
#
#                                  RadiologyOccurrenceID  \
# 0    GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...
# 1    GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...
# 2    GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...
# 3    GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...
# 4    GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...
# ..                                                 ...
# 119  GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...
# 120  GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...
# 121  GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...
# 122  GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...
# 123  GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...
#
#                                              PatientID  ImageResolutionRows  \
# 0    90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...                  320
# 1    90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...                  320
# 2    90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...                  320
# 3    90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...                  320
# 4    90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...                  320
# ..                                                 ...                  ...
# 119  90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...                  480
# 120  90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...                  480
# 121  90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...                  480
# 122  90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...                  480
# 123  90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...                  800
#
#      ImageResolutionColumns SliceThickness       ProtocolName  \
# 0                       320             10             SURVEY
# 1                       320             10             SURVEY
# 2                       320             10             SURVEY
# 3                       320             10             SURVEY
# 4                       320             10             SURVEY
# ..                      ...            ...                ...
# 119                     480              4  T2/FLAIR/AX CLEAR
# 120                     480              4  T2/FLAIR/AX CLEAR
# 121                     480              4  T2/FLAIR/AX CLEAR
# 122                     480              4  T2/FLAIR/AX CLEAR
# 123                     800             NA                 NA
#
#     PerformedProcedureStepDescription BodyPartExamined Modality  \
# 0                          MRI(BRAIN)                        MR
# 1                          MRI(BRAIN)                        MR
# 2                          MRI(BRAIN)                        MR
# 3                          MRI(BRAIN)                        MR
# 4                          MRI(BRAIN)                        MR
# ..                                ...              ...      ...
# 119                        MRI(BRAIN)                        MR
# 120                        MRI(BRAIN)                        MR
# 121                        MRI(BRAIN)                        MR
# 122                        MRI(BRAIN)                        MR
# 123                                NA               NA       MR
#
#     SeriesDescription    StudyDescription             Manufacturer  ImageNo  \
# 0              SURVEY  [¿ÜºÎCD]MRI(BRAIN)  Philips Medical Systems        1
# 1              SURVEY  [¿ÜºÎCD]MRI(BRAIN)  Philips Medical Systems        2
# 2              SURVEY  [¿ÜºÎCD]MRI(BRAIN)  Philips Medical Systems        3
# 3              SURVEY  [¿ÜºÎCD]MRI(BRAIN)  Philips Medical Systems        4
# 4              SURVEY  [¿ÜºÎCD]MRI(BRAIN)  Philips Medical Systems        5
# ..                ...                 ...                      ...      ...
# 119       T2/FLAIR/AX  [¿ÜºÎCD]MRI(BRAIN)  Philips Medical Systems       17
# 120       T2/FLAIR/AX  [¿ÜºÎCD]MRI(BRAIN)  Philips Medical Systems       18
# 121       T2/FLAIR/AX  [¿ÜºÎCD]MRI(BRAIN)  Philips Medical Systems       19
# 122       T2/FLAIR/AX  [¿ÜºÎCD]MRI(BRAIN)  Philips Medical Systems       20
# 123                NA  [¿ÜºÎCD]MRI(BRAIN)  Philips Medical Systems        1
#
#      PhaseTotalNo
# 0               5
# 1               5
# 2               5
# 3               5
# 4               5
# ..            ...
# 119            20
# 120            20
# 121            20
# 122            20
# 123             1
#
# [124 rows x 17 columns]

# %%
def StudyDateFunction(x):
    try:
        return Metadata[x].StudyDate
    except:
        return ''
def StudyTimeFunction(x):
    try:
        return Metadata[x].StudyTime[0:6]
    except:
        return ''
    
StudyDate=list(map(lambda x : StudyDateFunction(x), range(len(DICOMlist))))
StudyTime=list(map(lambda x : StudyTimeFunction(x), range(len(DICOMlist))))

def StudyDateTime(x):
    DateTime=StudyDate[x]+StudyTime[x]
    try:
        return str(datetime.strptime(DateTime, '%Y%m%d%H%M%S'))
    except:
        try:
            return str(datetime.strptime(DateTime, '%Y%m%d'))
        except:
            return str(datetime.strptime(DateTime, ''))

# %%
def Manufacturer(x):
    try:
        return Metadata[x].Manufacturer
    except:
        return 'NA'

# %%
def Modality(x):
    try:
        return Metadata[x].Modality
    except:
        return 'NA'

# %%
RadiologyOccurrenceTable=pd.DataFrame({'RadiologyOccurrenceID':list(map(lambda x : StudyInstanceUIDFunction(x), range(len(DICOMlist)))), 
                                       'StudyDateTime':list(map(lambda x : StudyDateTime(x), range(len(DICOMlist)))), 
                                       'PatientID':list(map(lambda x : PatientIDFunction(x), range(len(DICOMlist)))), 
                                       'Manufacturer':list(map(lambda x : Manufacturer(x), range(len(DICOMlist)))), 
                                       'Modality':list(map(lambda x : Modality(x), range(len(DICOMlist))))})

# %%
RadiologyOccurrenceTable.groupby('RadiologyOccurrenceID').first().reset_index()
# Out:
#                                RadiologyOccurrenceID        StudyDateTime  \
# 0  GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...  2010-03-25 14:52:55
#
#                                            PatientID             Manufacturer  \
# 0  90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...  Philips Medical Systems
#
#   Modality
# 0       MR

# %%
RadiologyOccurrenceTable
# Out:
#                                  RadiologyOccurrenceID        StudyDateTime  \
# 0    GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...  2010-03-25 14:52:55
# 1    GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...  2010-03-25 14:52:55
# 2    GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...  2010-03-25 14:52:55
# 3    GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...  2010-03-25 14:52:55
# 4    GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...  2010-03-25 14:52:55
# ..                                                 ...                  ...
# 119  GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...  2010-03-25 14:52:55
# 120  GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...  2010-03-25 14:52:55
# 121  GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...  2010-03-25 14:52:55
# 122  GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...  2010-03-25 14:52:55
# 123  GnPNqCtLxLJ4DZZc+R6UklR1grLBwcaKrzggzmSzby6gJk...  2010-03-25 14:52:55
#
#                                              PatientID  \
# 0    90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...
# 1    90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...
# 2    90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...
# 3    90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...
# 4    90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...
# ..                                                 ...
# 119  90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...
# 120  90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...
# 121  90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...
# 122  90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...
# 123  90wypvsLSe6mjyeWrrRu+/dMMqb7C0nupo8nlq60bvv3TD...
#
#                 Manufacturer Modality
# 0    Philips Medical Systems       MR
# 1    Philips Medical Systems       MR
# 2    Philips Medical Systems       MR
# 3    Philips Medical Systems       MR
# 4    Philips Medical Systems       MR
# ..                       ...      ...
# 119  Philips Medical Systems       MR
# 120  Philips Medical Systems       MR
# 121  Philips Medical Systems       MR
# 122  Philips Medical Systems       MR
# 123  Philips Medical Systems       MR
#
# [124 rows x 5 columns]
